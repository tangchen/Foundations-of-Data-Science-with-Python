# %% [markdown]
# # Random Variables (Outline)
# ## Discrete Random Variables and Probability Mass Functions
# ## Cumulative Distribution Functions and Their Properties
# ## Common Discrete Random Variables and Their Applications
# ## Generating, Simulating, and Characterizing Discrete Random Variables
# ## Continuous Random Variables and Probability Density Functions
# ## Properties of Probability Density Functions
# ## Common Continuous Random Variables and Their Applications
# ## The Central Limit Theorem and Gaussian Random Variables
# ## Generating, Simulating, and Characterizing Continuous Random Variables (including Kernel Density Estimation)
# ## Introduction to Conditioning with Random Variables
# ## Generative Classification
# ## Review
# ## Summary
