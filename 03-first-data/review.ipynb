# %% [markdown]
# # Review

# %% [markdown]
# In this Chapter, we started working with real data, introduced Pands, partitions, summary statistics, binary hypothesis testing via bootstrap resampling, and two-dimensional statistics.

# %%
from IPython.core.display import display, HTML
import random
import string

def display_quiz (question, answers, multiple=False, randomize=True,
                          question_background="#6F78FF"):
    
    num_correct=0
    
    question_start='''<div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
      <!-- QUESTION -->
      <div id="quizQn" style="padding: 20px;
      background: '''
    question_mid=''';
      color: #fff;
      font-size: 20px;
      border-radius: 10px;">
      '''
    question_end='</div>'

    answer_start='''
      <!-- ANSWER -->
      <div id="quizAns" style="margin: 10px 0;
      display: grid;
      grid-template-columns: auto auto;
      grid-gap: 10px;">
      '''
    quiz_html=question_start+question_background+question_mid \
        +question+question_end+answer_start


    letters = string.ascii_letters
    feedback_id= ''.join(random.choice(letters) for i in range(12)) 
    #print(feedback_id)
    
    input_start='''<input type="radio" name="quiz" id="quizo'''
    input_end='''" style="display:none;" >'''
    label_start='''<label style="background: #fafafa;
      border: 1px solid #eee;  border-radius: 10px; padding: 10px;
      font-size: 16px; cursor: pointer; text-align: center;" 
      onclick="check'''
    label_start+=feedback_id
    label_start+='''()" 
      id="quizo'''
    label_end='''  </label>'''

    
    if randomize:
        random.shuffle(answers)
    for i, answer in enumerate(answers):
        #quiz_html+=input_start+str(i)+ '" data-correct="' +str(answer["correct"]) \
        quiz_html+=input_start+str(i) +input_end
        quiz_html+=label_start+str(i) \
        + '" data-correct="' +str(answer["correct"]) \
        + '" data-feedback="' +str(answer["feedback"]) \
        +'" data-answered=0>'+answer["answer"]+label_end
        if answer["correct"]:
            num_correct+=1

    quiz_html+='''  </div></div>
    <div id="'''
    
    quiz_html+=feedback_id
    quiz_html+='''" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect='''
    quiz_html+=str(num_correct) + '''></div>'''

    javascript = """
        <script type="text/Javascript">

        function check"""
    javascript+=feedback_id
    if multiple:
        javascript+="""(){

                console.log(event.srcElement.id)           
                console.log(event.srcElement.dataset.correct)   
                console.log(event.srcElement.dataset.feedback)

                answers= event.srcElement.parentElement.children;
                console.log(answers);

                var feedback = document.getElementById("""
        javascript+='"'+feedback_id+'"'
        javascript+=""");
                reset = false;
                if (event.srcElement.dataset.correct=="True" )   {
                    if (event.srcElement.dataset.answered<=0) {
                        if (feedback.dataset.answeredcorrect<0) {
                            feedback.dataset.answeredcorrect=1;
                            reset=true;
                        } else {
                           feedback.dataset.answeredcorrect++;
                        }
                        if (reset) {
                            for (var i = 0; i < answers.length; i++) {
                                child=answers[i];
                                child.style.background="#fafafa";
                                child.dataset.answered=0;
                            }
                        }
                        event.srcElement.style.background="#d8ffc4";
                        event.srcElement.dataset.answered=1;
                        feedback.style.color="#009113";

                    }
                } else {
                    if (feedback.dataset.answeredcorrect>0) {
                        feedback.dataset.answeredcorrect=-1;
                        reset=true;
                    } else {
                       feedback.dataset.answeredcorrect--;
                    }

                    if (reset) {
                        for (var i = 0; i < answers.length; i++) {
                            child=answers[i];
                            child.style.background="#fafafa";
                            child.dataset.answered=0;
                        }
                    }
                    event.srcElement.style.background="#ffe8e8";
                    feedback.style.color="#DC2329";
                }


                numcorrect=feedback.dataset.numcorrect;
                answeredcorrect=feedback.dataset.answeredcorrect;
                if (answeredcorrect>=0) {
                    feedback.innerHTML=event.srcElement.dataset.feedback + " [" \
                + answeredcorrect + "/" + numcorrect + "]";
                } else {
                    feedback.innerHTML=event.srcElement.dataset.feedback + "[" \
                + 0 + "/" + numcorrect + "]";
                }


            }

        </script>
        """
    else:
        javascript+="""(){

                console.log(event.srcElement.id)           
                console.log(event.srcElement.dataset.correct)   
                console.log(event.srcElement.dataset.feedback)

                answers= event.srcElement.parentElement.children;
                console.log(answers);

                for (var i = 0; i < answers.length; i++) {
                    child=answers[i];
                    child.style.background="#fafafa";
                }
                var feedback = document.getElementById("""
        javascript+='"'+feedback_id+'"'
        javascript+=""");
                feedback.innerHTML=event.srcElement.dataset.feedback;
                if (event.srcElement.dataset.correct=="True")   {
                    event.srcElement.style.background="#d8ffc4";
                    feedback.style.color="#009113";
                } else {
                    event.srcElement.style.background="#ffe8e8";
                    feedback.style.color="#DC2329";
                }




            }

        </script>
        """
    #print(javascript)

    display(HTML(quiz_html+javascript))

# %% [markdown]
# **Self-assessment:**

# %%
question='''Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:'''
answers=[
    {'answer':"sum of squared errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "sum of absolute errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "total number of errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "sum of errors",
     'correct': False,
     'feedback': "There is no minimum value for this metric."
    }
]


display_quiz(question, answers, multiple=True,
             question_background="#feb44A")
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #feb44A;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkbFHlrZujmdis()"
#       id="quizo0" data-correct="False" data-feedback="There is no minimum value for this metric." data-answered=0>sum of errors  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkbFHlrZujmdis()"
#       id="quizo1" data-correct="True" data-feedback="Correct." data-answered=0>sum of absolute errors  </label><input type="radio" name="quiz" id="quizo2" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkbFHlrZujmdis()"
#       id="quizo2" data-correct="True" data-feedback="Correct." data-answered=0>sum of squared errors  </label><input type="radio" name="quiz" id="quizo3" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkbFHlrZujmdis()"
#       id="quizo3" data-correct="True" data-feedback="Correct." data-answered=0>total number of errors  </label>  </div></div>
#     <div id="bFHlrZujmdis" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect=3></div>
#         <script type="text/Javascript">
#
#         function checkbFHlrZujmdis(){
#
#                 console.log(event.srcElement.id)
#                 console.log(event.srcElement.dataset.correct)
#                 console.log(event.srcElement.dataset.feedback)
#
#                 answers= event.srcElement.parentElement.children;
#                 console.log(answers);
#
#                 var feedback = document.getElementById("bFHlrZujmdis");
#                 reset = false;
#                 if (event.srcElement.dataset.correct=="True" )   {
#                     if (event.srcElement.dataset.answered<=0) {
#                         if (feedback.dataset.answeredcorrect<0) {
#                             feedback.dataset.answeredcorrect=1;
#                             reset=true;
#                         } else {
#                            feedback.dataset.answeredcorrect++;
#                         }
#                         if (reset) {
#                             for (var i = 0; i < answers.length; i++) {
#                                 child=answers[i];
#                                 child.style.background="#fafafa";
#                                 child.dataset.answered=0;
#                             }
#                         }
#                         event.srcElement.style.background="#d8ffc4";
#                         event.srcElement.dataset.answered=1;
#                         feedback.style.color="#009113";
#
#                     }
#                 } else {
#                     if (feedback.dataset.answeredcorrect>0) {
#                         feedback.dataset.answeredcorrect=-1;
#                         reset=true;
#                     } else {
#                        feedback.dataset.answeredcorrect--;
#                     }
#
#                     if (reset) {
#                         for (var i = 0; i < answers.length; i++) {
#                             child=answers[i];
#                             child.style.background="#fafafa";
#                             child.dataset.answered=0;
#                         }
#                     }
#                     event.srcElement.style.background="#ffe8e8";
#                     feedback.style.color="#DC2329";
#                 }
#
#
#                 numcorrect=feedback.dataset.numcorrect;
#                 answeredcorrect=feedback.dataset.answeredcorrect;
#                 if (answeredcorrect>=0) {
#                     feedback.innerHTML=event.srcElement.dataset.feedback + " ["                 + answeredcorrect + "/" + numcorrect + "]";
#                 } else {
#                     feedback.innerHTML=event.srcElement.dataset.feedback + "["                 + 0 + "/" + numcorrect + "]";
#                 }
#
#
#             }
#
#         </script>

# %%
question='''Which of the following summary statistics minimizes the sum of squared errors to the data:'''
answers=[
    {'answer':"average",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "median",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "mode",
     'correct': False,
     'feedback': "Try again."
    }
]


display_quiz(question, answers, )
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #6F78FF;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the sum of squared errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkHWDlyzbxwltL()"
#       id="quizo0" data-correct="False" data-feedback="Try again." data-answered=0>mode  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkHWDlyzbxwltL()"
#       id="quizo1" data-correct="True" data-feedback="Correct." data-answered=0>average  </label><input type="radio" name="quiz" id="quizo2" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkHWDlyzbxwltL()"
#       id="quizo2" data-correct="False" data-feedback="Try again." data-answered=0>median  </label>  </div></div>
#     <div id="HWDlyzbxwltL" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect=1></div>
#         <script type="text/Javascript">
#
#         function checkHWDlyzbxwltL(){
#
#                 console.log(event.srcElement.id)
#                 console.log(event.srcElement.dataset.correct)
#                 console.log(event.srcElement.dataset.feedback)
#
#                 answers= event.srcElement.parentElement.children;
#                 console.log(answers);
#
#                 for (var i = 0; i < answers.length; i++) {
#                     child=answers[i];
#                     child.style.background="#fafafa";
#                 }
#                 var feedback = document.getElementById("HWDlyzbxwltL");
#                 feedback.innerHTML=event.srcElement.dataset.feedback;
#                 if (event.srcElement.dataset.correct=="True")   {
#                     event.srcElement.style.background="#d8ffc4";
#                     feedback.style.color="#009113";
#                 } else {
#                     event.srcElement.style.background="#ffe8e8";
#                     feedback.style.color="#DC2329";
#                 }
#
#
#
#
#             }
#
#         </script>

# %%
question='''Which of the following summary statistics minimizes the sum of absolute errors to the data:'''
answers=[
    {'answer':"average",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "median",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "mode",
     'correct': False,
     'feedback': "Try again."
    }
]


display_quiz(question, answers)
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #6F78FF;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the sum of absolute errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checksMfCtPxiVboz()"
#       id="quizo0" data-correct="False" data-feedback="Try again." data-answered=0>average  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checksMfCtPxiVboz()"
#       id="quizo1" data-correct="True" data-feedback="Correct." data-answered=0>median  </label><input type="radio" name="quiz" id="quizo2" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checksMfCtPxiVboz()"
#       id="quizo2" data-correct="False" data-feedback="Try again." data-answered=0>mode  </label>  </div></div>
#     <div id="sMfCtPxiVboz" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect=1></div>
#         <script type="text/Javascript">
#
#         function checksMfCtPxiVboz(){
#
#                 console.log(event.srcElement.id)
#                 console.log(event.srcElement.dataset.correct)
#                 console.log(event.srcElement.dataset.feedback)
#
#                 answers= event.srcElement.parentElement.children;
#                 console.log(answers);
#
#                 for (var i = 0; i < answers.length; i++) {
#                     child=answers[i];
#                     child.style.background="#fafafa";
#                 }
#                 var feedback = document.getElementById("sMfCtPxiVboz");
#                 feedback.innerHTML=event.srcElement.dataset.feedback;
#                 if (event.srcElement.dataset.correct=="True")   {
#                     event.srcElement.style.background="#d8ffc4";
#                     feedback.style.color="#009113";
#                 } else {
#                     event.srcElement.style.background="#ffe8e8";
#                     feedback.style.color="#DC2329";
#                 }
#
#
#
#
#             }
#
#         </script>

# %%
question='''Which of the following summary statistics minimizes the number of non-zero errors to the data:'''
answers=[
    {'answer':"average",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "median",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "mode",
     'correct': True,
     'feedback': "Correct."
    }
]


display_quiz(question, answers)
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #6F78FF;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the number of non-zero errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkUralMFDEJtgm()"
#       id="quizo0" data-correct="False" data-feedback="Try again." data-answered=0>median  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkUralMFDEJtgm()"
#       id="quizo1" data-correct="True" data-feedback="Correct." data-answered=0>mode  </label><input type="radio" name="quiz" id="quizo2" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkUralMFDEJtgm()"
#       id="quizo2" data-correct="False" data-feedback="Try again." data-answered=0>average  </label>  </div></div>
#     <div id="UralMFDEJtgm" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect=1></div>
#         <script type="text/Javascript">
#
#         function checkUralMFDEJtgm(){
#
#                 console.log(event.srcElement.id)
#                 console.log(event.srcElement.dataset.correct)
#                 console.log(event.srcElement.dataset.feedback)
#
#                 answers= event.srcElement.parentElement.children;
#                 console.log(answers);
#
#                 for (var i = 0; i < answers.length; i++) {
#                     child=answers[i];
#                     child.style.background="#fafafa";
#                 }
#                 var feedback = document.getElementById("UralMFDEJtgm");
#                 feedback.innerHTML=event.srcElement.dataset.feedback;
#                 if (event.srcElement.dataset.correct=="True")   {
#                     event.srcElement.style.background="#d8ffc4";
#                     feedback.style.color="#009113";
#                 } else {
#                     event.srcElement.style.background="#ffe8e8";
#                     feedback.style.color="#DC2329";
#                 }
#
#
#
#
#             }
#
#         </script>

# %%
question='''Choose all of the following that are typical causes of outliers in data sets:'''
answers=[
    {'answer':"data entry errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "unit conversion errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "measurement errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "different population characteristics",
     'correct': False,
     'feedback': "Different population characteristics often produce variations in data, but these are not erroneous values and not considered outliers."
    }
]


display_quiz(question, answers, multiple=True,
             question_background="#feb44A")
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #feb44A;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Choose all of the following that are typical causes of outliers in data sets:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkdXPwlkhRciJK()"
#       id="quizo0" data-correct="False" data-feedback="Different population characteristics often produce variations in data, but these are not erroneous values and not considered outliers." data-answered=0>different population characteristics  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkdXPwlkhRciJK()"
#       id="quizo1" data-correct="True" data-feedback="Correct." data-answered=0>unit conversion errors  </label><input type="radio" name="quiz" id="quizo2" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkdXPwlkhRciJK()"
#       id="quizo2" data-correct="True" data-feedback="Correct." data-answered=0>measurement errors  </label><input type="radio" name="quiz" id="quizo3" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkdXPwlkhRciJK()"
#       id="quizo3" data-correct="True" data-feedback="Correct." data-answered=0>data entry errors  </label>  </div></div>
#     <div id="dXPwlkhRciJK" style="font-size: 20px;text-align:center;" data-answeredcorrect=0 data-numcorrect=3></div>
#         <script type="text/Javascript">
#
#         function checkdXPwlkhRciJK(){
#
#                 console.log(event.srcElement.id)
#                 console.log(event.srcElement.dataset.correct)
#                 console.log(event.srcElement.dataset.feedback)
#
#                 answers= event.srcElement.parentElement.children;
#                 console.log(answers);
#
#                 var feedback = document.getElementById("dXPwlkhRciJK");
#                 reset = false;
#                 if (event.srcElement.dataset.correct=="True" )   {
#                     if (event.srcElement.dataset.answered<=0) {
#                         if (feedback.dataset.answeredcorrect<0) {
#                             feedback.dataset.answeredcorrect=1;
#                             reset=true;
#                         } else {
#                            feedback.dataset.answeredcorrect++;
#                         }
#                         if (reset) {
#                             for (var i = 0; i < answers.length; i++) {
#                                 child=answers[i];
#                                 child.style.background="#fafafa";
#                                 child.dataset.answered=0;
#                             }
#                         }
#                         event.srcElement.style.background="#d8ffc4";
#                         event.srcElement.dataset.answered=1;
#                         feedback.style.color="#009113";
#
#                     }
#                 } else {
#                     if (feedback.dataset.answeredcorrect>0) {
#                         feedback.dataset.answeredcorrect=-1;
#                         reset=true;
#                     } else {
#                        feedback.dataset.answeredcorrect--;
#                     }
#
#                     if (reset) {
#                         for (var i = 0; i < answers.length; i++) {
#                             child=answers[i];
#                             child.style.background="#fafafa";
#                             child.dataset.answered=0;
#                         }
#                     }
#                     event.srcElement.style.background="#ffe8e8";
#                     feedback.style.color="#DC2329";
#                 }
#
#
#                 numcorrect=feedback.dataset.numcorrect;
#                 answeredcorrect=feedback.dataset.answeredcorrect;
#                 if (answeredcorrect>=0) {
#                     feedback.innerHTML=event.srcElement.dataset.feedback + " ["                 + answeredcorrect + "/" + numcorrect + "]";
#                 } else {
#                     feedback.innerHTML=event.srcElement.dataset.feedback + "["                 + 0 + "/" + numcorrect + "]";
#                 }
#
#
#             }
#
#         </script>

# %% [markdown]
# **Key Take-aways:**
# * Pandas stores data in dataframes. **Dataframes store tabular data, like spreadsheets or database tables.**
# * **Pandas can import data from standard file formats**, including comma-separated value (CSV) files and Excel files.
# * **Scatter plots are useful for initial data exploration and identifying outliers.**
# * **Partitions divide data into disjoint subsets.**
# * **Summary statistics represent a group of data by a single number.**
# * **Common summary statistics minimize a measure of error from the summary statistic to the data:**
#     * Mode minimizes the *error count*.
#     * Median minimizes the *sum of absolute errors*.
#     * Average, or sample mean, minimizes the *sum of squared errors*.
# * A **statistical hypothesis is a hypothesis that is testable using data.**
# * A **binary hypothesis test is a statistical test that decides between two competing statistical hypotheses.**
#     * A **null hypothesis, denoted $H_0$ assumes that the data being evaluated come from the same underlying random phenomena**. Observed differences are caused by random sampling.
# * **Resampling is a model-free technique to draw new samples of data for use in statistical testing.**
#     * **Bootstrap resampling is when data is drawn from the pooled data with replacement.**
# * **Two-dimensional statistical methods can be used to directly work with pairs of data** through techniques such as curve fitting.
