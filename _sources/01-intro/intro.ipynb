# %% [markdown]
# # Introduction
#
# Welcome to *Introduction to Data Science for Engineers*. This chapter provides an introduction to the book and its place in the field of data science, and then provides a brief introduction to some of the tools that are used throughout the book.
